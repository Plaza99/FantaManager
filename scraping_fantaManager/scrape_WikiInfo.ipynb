# %%
import json
array_players=(json.load(open("listplayer.json")))

# %%
array_players
# Out:
# ['Ciro Immobile',
#  'Dusan Vlahovic',
#  'Lautaro Martínez',
#  'Tammy Abraham',
#  'Giovanni Simeone',
#  'Gianluca Scamacca',
#  'Domenico Berardi',
#  'Marko Arnautovic',
#  'Victor Osimhen',
#  'Gerard Deulofeu',
#  'Mario Pasalic',
#  'Edin Dzeko',
#  'João Pedro',
#  'Andrea Pinamonti',
#  'Gianluca Caprari',
#  'Olivier Giroud',
#  'Dries Mertens',
#  'Lorenzo Insigne',
#  'Sergej Milinkovic-Savic',
#  'Antonin Barak',
#  'Francesco Caputo',
#  'Rafael Leão',
#  'Beto',
#  'Duván Zapata',
#  'Paulo Dybala',
#  'Federico Bonazzoli',
#  'Giacomo Raspadori',
#  'Pedro',
#  'Luis Muriel',
#  'Lorenzo Pellegrini',
#  'Mattia Destro',
#  'Álvaro Morata',
#  'Thomas Henry',
#  'Ivan Perisic',
#  'Andrea Belotti',
#  'Zlatan Ibrahimovic',
#  'Daniele Verde',
#  'Hakan Calhanoglu',
#  'Manolo Gabbiadini',
#  'Antonio Candreva',
#  'Mattia Aramu',
#  'Fabián',
#  'Josip Brekalo',
#  'Hamed Junior Traore',
#  'Nicolás González',
#  'Nahuel Molina',
#  'David Okereke',
# ...

# %%
len(array_players)
# Out:
# 608

# %%
import wikipedia as wiki
import time
totalScrapedInfo=[]
for i in range(608):
    scrapedInfo={}
    story={}
    try:
        page = wiki.page(array_players[i], auto_suggest=False)
    #time.sleep(8)
        text=page.summary
    except:
        text=None
    story["Career"]=text
    scrapedInfo[array_players[i]]=story
    print(scrapedInfo)
    totalScrapedInfo.append(scrapedInfo)
# Out:
# {'Ciro Immobile': {'Career': "Ciro Immobile  (born 20 February 1990) is an Italian professional footballer who plays as a striker for Serie A club Lazio, which he captains, and the Italy national team.\nImmobile began his career at Sorrento. In 2009, he was purchased by Juventus, and was later loaned out to three Serie B clubs, including Pescara, with whom he won the league title as the top scorer, before moving to Genoa in 2012. After a season with the club, he moved to Juventus' rivals Torino. At Torino, he won the Capocannoniere award for the top scorer in Serie A. After his breakout season at Torino, he was sold to German club Borussia Dortmund for around €18 million in 2014, where they won the DFL-Supercup, before moving to Spanish club Sevilla in 2015. In 2016, he returned to Torino on loan, and was later sold to Lazio in July of that year. In his second season at Lazio, he won the Capocannoniere for a second time, with 29 goals in 33 games. The 2019–20 season was the most prol
# ...

# %%
import csv
import json

        
file = open('carrier_player.json', mode='w', encoding='utf-8')
file.write(json.dumps(array_players))
# Out:
# 11406
